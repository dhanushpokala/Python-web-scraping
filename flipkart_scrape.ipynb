# %%
# !pip install requests
# !pip install bs4
from bs4 import BeautifulSoup
import requests
# Out:
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\anaconda\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: bs4 in d:\anaconda\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %%
url='https://www.flipkart.com/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6CCRNPX5K&lid=LSTTSHFZMJ6CCRNPX5KB1BXDF&marketplace=FLIPKART&q=t+shirts&store=clo%2Fash%2Fank%2Fedy&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&fm=SEARCH&iid=8d42db2d-de9d-41c5-b5d6-0c3a5a8572b7.TSHFZMJ6CCRNPX5K.SEARCH&ppt=sp&ppn=sp&qH=04ad3bdbbe706182'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'
}
page=requests.get(url=url,headers=headers)

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content,'html.parser')
soup2=BeautifulSoup(soup.prettify(),'html.parser')

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
# <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8a1772.css" rel="stylesheet"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@flipkart" name="twitter:site"/>
# <meta content="@flipkart" name="twitter:creator"/>
# <meta content="Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt - Buy Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt Online at Best Prices in India | Flipkart.com" name="twitter:title"/>
# <meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/>
# <meta content="http://rukmini1.flixcart.com/image/300/300/kkec4280/t-shirt/b/m/i/l-t345-blwhrd-new-eyebogler-original-imafzr4f7nxecr44.jpeg" property="twitter:image"/>
# <meta content="in" name="twitter:app:country">
# <meta content="Flipkart" name="al:ios:app_name"/>
# <meta content="742044692" name="al:ios:app_store_id"/>
# <meta content="Flipkart" name="twitter:app:name:iphone"/>
# <meta content="742044692" name="twitter:app:id:iphone"/>
# <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/>
# <meta content="Flipkart" name="twitter:app:name:ipad"/>
# <meta content="742044692" name="twitter:app:id:ipad"/>
# <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/>
# <meta content="Flipkart" name="twitter:app:name:googleplay"/>
# <meta content="com.flipkart.android" name="twitter:app:id:googleplay"/>
# <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/>
# <style>
#     #container {
# 			height: 100%;
# 		}
#    </style>
# <script nonce="13834811178714706440" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/polyfills.chunk.61cc5aba.js">
# </script>
# <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/runtime.6a4f3102.js">
# </script>
# <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/vendor.chunk.720a4da6.js">
# </script>
# <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/app_modules.chunk.e0c0ff04.js">
# </script>
# <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/app_common.chunk.61f69076.js">
# </script>
# <script crossorigin="anonymous" defer="defer" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/app.chunk.5c3624c1.js">
# </script>
# <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/Product.chunk.1b90a8.css" rel="stylesheet"/>
# <title>
#     Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt - Buy Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt Online at Best Prices in India | Flipkart.com
#    </title>
# <meta content="Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt - Buy Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt Online at Best Prices in India | Flipkart.com" name="og_title" property="og:title"/>
# <meta content="Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt, Clothing" name="Keywords"/>
# <meta content="Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt - Buy Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt For Only Rs. 1299 Online in India. Shop Online For Apparels. Huge Collection of Branded Clothes Only at Flipkart.com" name="Description"/>
# <meta content="Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt - Buy Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt For Only Rs. 1299 Online in India. Shop Online For Apparels. Huge Collection of Branded Clothes Only at Flipkart.com" property="og:description"/>
# <link href="https://www.flipkart.com/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa" rel="canonical"/>
# <link href="android-app://com.flipkart.android/flipkart/de_pp_seg_--_ITM5B837B35126FA" rel="alternate"/>
# <meta content="http://rukmini1.flixcart.com/image/300/300/kkec4280/t-shirt/b/m/i/l-t345-blwhrd-new-eyebogler-original-imafzr4f7nxecr44.jpeg" name="og_image" property="og:image"/>
# <meta content="https://www.flipkart.com/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa" name="og_url" property="og:url"/>
# <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01"/>
# <!--[if IE 9 ]>
# 	<script nonce="13834811178714706440">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]-->
# <!--[if !IE]><!-->
# <script nonce="13834811178714706440">
#            if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}
#           </script>
# <!--<![endif]-->
# <script id="jsonLD" nonce="13834811178714706440" type="application/ld+json">
#            [{"@context":"http://schema.org","@type":"Product","aggregateRating":{"@type":"AggregateRating","ratingValue":4,"reviewCount":1462},"brand":{"@type":"Thing","name":"Eyebogler"},"image":"http://rukmini1.flixcart.com/image/128/128/kkec4280/t-shirt/b/m/i/l-t345-blwhrd-new-eyebogler-original-imafzr4f7nxecr44.jpeg?q=70","name":"Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt"},{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":{"@id":"https://www.flipkart.com/?otracker=product_breadCrumbs_Home","name":"Home"},"position":1},{"@type":"ListItem","item":{"@id":"https://www.flipkart.com/clothing-and-accessories/pr?sid=clo&marketplace=FLIPKART&otracker=product_breadCrumbs_Clothing+and+Accessories","name":"Clothing and Accessories"},"position":2},{"@type":"ListItem","item":{"@id":"https://www.flipkart.com/clothing-and-accessories/topwear/pr?sid=clo,ash&marketplace=FLIPKART&otracker=product_breadCrumbs_Topwear","name":"Topwear"},"position":3},{"@type":"ListItem","item":{"@id":"https://www.flipkart.com/clothing-and-accessories/topwear/tshirts/pr?sid=clo,ash,ank&marketplace=FLIPKART&otracker=product_breadCrumbs_T-shirts","name":"T-shirts"},"position":4},{"@type":"ListItem","item":{"@id":"https://www.flipkart.com/mens-tshirts/pr?sid=clo,ash,ank,edy&marketplace=FLIPKART&otracker=product_breadCrumbs_Men%27s+T-shirts","name":"Men's T-shirts"},"position":5},{"@type":"ListItem","item":{"@id":"https://www.flipkart.com/mens-tshirts/eyebogler~brand/pr?sid=clo,ash,ank,edy&marketplace=FLIPKART&otracker=product_breadCrumbs_Eyebogler+Men%27s+T-shirts","name":"Eyebogler Men's T-shirts"},"position":6},{"@type":"ListItem","item":{"@id":"https://www.flipkart.com/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa?otracker=product_breadCrumbs_Eyebogler+Color+Block+Men+Hooded+Neck+White%2C+Red%2C+Black+T-Shirt","name":"Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt"},"position":7}]}]
#           </script>
# <script nonce="13834811178714706440">
#            !function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#           </script>
# <script nonce="13834811178714706440">
#            if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#           </script>
# <script nonce="13834811178714706440">
#            // web-vitals polyfill for FID
#         !function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);
#           </script>
# </meta>
# </head>
# <body>
# <div id="container">
# <div data-reactroot="">
# <div class="_1kfTjk">
# <div class="_1rH5Jn">
# <div class="_1TmfNK">
# </div>
# <div class="_2Xfa2_">
# <div class="_3_C9Hx">
# <div class="_3qX0zy">
# <a href="/">
# <img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/>
# </a>
# <a class="_21ljIi" href="/plus">
#           Explore
#           <!-- -->
# <span class="_2FVHGh">
#            Plus
#           </span>
# <img src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/plus_aef861.png" width="10"/>
# </a>
# </div>
# </div>
# <div class="_1cmsER">
# <form action="/search" class="_2M8cLY header-form-search" method="GET">
# <div class="col-12-12 _2oO9oE">
# <div class="_3OO5Xc">
# <input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/>
# </div>
# <button class="L0Z3Pu" type="submit">
# <svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg">
# <g fill="#2874F1" fill-rule="evenodd">
# <path class="_34RNph" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203">
# </path>
# <path class="_34RNph" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467">
# </path>
# </g>
# </svg>
# </button>
# <input name="otracker" type="hidden" value="search"/>
# <input name="otracker1" type="hidden" value="search"/>
# <input name="marketplace" type="hidden" value="FLIPKART"/>
# <input name="as-show" type="hidden" value="off"/>
# <input name="as" type="hidden" value="off"/>
# </div>
# <ul class="col-12-12 _1MRYA1">
# </ul>
# </form>
# </div>
# <div class="go_DOp _2errNR">
# <div class="_28p97w">
# <div class="_1psGvi _3BvnxG">
# <div>
# <a class="_1_3w1N" href="/account/login?ret=/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa%3Fpid%3DTSHFZMJ6CCRNPX5K%26lid%3DLSTTSHFZMJ6CCRNPX5KB1BXDF%26marketplace%3DFLIPKART%26q%3Dt%2Bshirts%26store%3Dclo%252Fash%252Fank%252Fedy%26srno%3Ds_1_2%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_1_na_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_1_na_na_na%26fm%3DSEARCH%26iid%3D8d42db2d-de9d-41c5-b5d6-0c3a5a8572b7.TSHFZMJ6CCRNPX5K.SEARCH%26ppt%3Dsp%26ppn%3Dsp%26qH%3D04ad3bdbbe706182">
#             Login
#            </a>
# </div>
# </div>
# </div>
# </div>
# <div class="go_DOp">
# <div class="_28p97w">
# <div class="_1psGvi _3BvnxG">
# <div>
# <div class="exehdJ">
# <!-- -->
#             More
#             <!-- -->
# </div>
# </div>
# </div>
# <svg class="zZ3yfL" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg">
# <path class="_2gTTdy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# </div>
# <div class="go_DOp">
# <div class="_1psGvi">
# <div class="YUhWwv">
# <a class="_3SkBxJ" href="/viewcart?otracker=Cart_Icon_Click">
# <svg class="V3C5bO" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg">
# <path class="_1bS9ic" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff">
# </path>
# </svg>
# <span>
#             Cart
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="_1TmfNK">
# </div>
# </div>
# <div class="_1mUdNz">
# </div>
# </div>
# <div class="_331-kn">
# </div>
# <div class="_2c7YLP UtUXW0 _6t1WkM _3HqJxg">
# <div class="_1YokD2 _2GoDe3" style="background-color:#FFFFFF;padding:16px 16px 16px 16px">
# <div class="_1YokD2 _3Mn1Gg col-5-12 _78xt5Y">
# <div class="_1AtVbE col-12-12">
# <div class="_1iyjIJ">
# <div class="_3li7GG">
# <div class="_35DpL- _2_B7hD">
# <div class="_2FHWw4">
# <div class="_2mLllQ" style="height:148px">
# <ul class="_3GnUWp" style="-webkit-transform:translateY(-0px);-moz-transform:translateY(-0px);-o-transform:translateY(-0px);-ms-transform:translateY(-0px);transform:translateY(-0px)">
# <li class="_20Gt85 _1Y_A6W _2_B7hD" style="height:74px">
# <div class="_1AuMiq P9aMAP _2_B7hD">
# <div class="q6DClP _2_B7hD" style="background-image:url(https://rukminim1.flixcart.com/image/128/128/kkec4280/t-shirt/b/m/i/l-t345-blwhrd-new-eyebogler-original-imafzr4f7nxecr44.jpeg?q=70)">
# </div>
# </div>
# </li>
# <li class="_20Gt85 _1Y_A6W _2_B7hD" style="height:74px">
# <div class="_1AuMiq _2_B7hD">
# <div class="q6DClP _2_B7hD" style="background-image:url(https://rukminim1.flixcart.com/image/128/128/kk8mcnk0/t-shirt/e/b/d/3xl-t345-blwhrd-new-eyebogler-original-imafzmj6kf6pkqcm.jpeg?q=70)">
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="_1VfWRb _3jywji YTKFIp">
# <svg class="_1YdSSj" height="15" viewbox="0 0 16 27" width="8" xmlns="http://www.w3.org/2000/svg">
# <path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#000">
# </path>
# </svg>
# </div>
# <div class="_1VfWRb VnysFO YTKFIp">
# <svg class="_1YdSSj" height="15" viewbox="0 0 16 27" width="8" xmlns="http://www.w3.org/2000/svg">
# <path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#000">
# </path>
# </svg>
# </div>
# </div>
# </div>
# <div class="_1BweB8 _2S1qQy">
# <div class="_3kidJX">
# <div class="_3A1TYz" style="height:0;width:0">
# </div>
# <div class="_3ywSr_" style="padding-top:120.00%">
# <div class="_312yBx SFzpgZ" style="padding-top:120.00%">
# <img alt="" class="_2r_T1I _396QI4" src=""/>
# </div>
# </div>
# </div>
# <div class="bXrC_t" style="left:0;width:0;height:0">
# <img class="_3_UeBw"/>
# </div>
# </div>
# </div>
# <div class="_2hVSre _25_uYi _2_B7hD -o7Q4n">
# <div class="_36FSn5">
# <svg class="_1l0elc" height="24" viewbox="0 0 20 16" width="24" xmlns="http://www.w3.org/2000/svg">
# <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
# </path>
# </svg>
# </div>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-12-12">
# <div class="_1p3MFP">
# <ul class="row">
# <li class="col col-6-12">
# <button class="_2KpZ6l _2U9uOA _3v1-ww">
# <svg class="_1KOMV2" height="16" viewbox="0 0 16 15" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff">
# </path>
# </svg>
# <!-- -->
#             ADD TO CART
#            </button>
# </li>
# <li class="col col-6-12">
# <form>
# <button class="_2KpZ6l _2U9uOA ihZ75k _3AWRsL" type="button">
# <span class="_3iRXzi">
# </span>
# <!-- -->
#              BUY NOW
#             </button>
# </form>
# </li>
# </ul>
# </div>
# </div>
# <div class="_1AtVbE col-12-12">
# </div>
# </div>
# <div class="_1YokD2 _3Mn1Gg col-8-12" style="padding:0px 0px 0px 24px">
# <div class="_1YokD2 _2GoDe3">
# <div class="_1AtVbE" style="flex-grow:1;overflow:auto">
# <div class="_1MR4o5">
# <div class="_3GIHBu">
# <a class="_2whKao" href="/?otracker=product_breadCrumbs_Home">
#             Home
#            </a>
# <svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# <div class="_3GIHBu">
# <a class="_2whKao" href="/clothing-and-accessories/pr?sid=clo&amp;marketplace=FLIPKART&amp;otracker=product_breadCrumbs_Clothing+and+Accessories">
#             Clothing and Accessories
#            </a>
# <svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# <div class="_3GIHBu">
# <a class="_2whKao" href="/clothing-and-accessories/topwear/pr?sid=clo,ash&amp;marketplace=FLIPKART&amp;otracker=product_breadCrumbs_Topwear">
#             Topwear
#            </a>
# <svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# <div class="_3GIHBu">
# <a class="_2whKao" href="/clothing-and-accessories/topwear/tshirts/pr?sid=clo,ash,ank&amp;marketplace=FLIPKART&amp;otracker=product_breadCrumbs_T-shirts">
#             T-shirts
#            </a>
# <svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# <div class="_3GIHBu">
# <a class="_2whKao" href="/mens-tshirts/pr?sid=clo,ash,ank,edy&amp;marketplace=FLIPKART&amp;otracker=product_breadCrumbs_Men%27s+T-shirts">
#             Men's T-shirts
#            </a>
# <svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# <div class="_3GIHBu">
# <a class="_2whKao" href="/mens-tshirts/eyebogler~brand/pr?sid=clo,ash,ank,edy&amp;marketplace=FLIPKART&amp;otracker=product_breadCrumbs_Eyebogler+Men%27s+T-shirts">
#             Eyebogler Men's T-shirts
#            </a>
# <svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# <div class="_3GIHBu">
# <div class="_1LJS6T _2whKao _1QoaG0">
# <div class="_2NKhZn">
# <p>
#               Eyebogler Color Block Men Hooded Neck White, Red, Black T-Shirt
#              </p>
# </div>
# </div>
# <svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# </div>
# </div>
# <div class="_1AtVbE" style="flex:0 0 70px;max-width:70px">
# <div class="_1GpbsQ">
# <div class="Bv11UC">
# <span class="">
# <span class="_2kXMeX">
# <svg class="Kj-yxs" height="18" width="18" xmlns="http://www.w3.org/2000/svg">
# <path class="_2bvlkb" d="M14.78 5.883L9.032 0v3.362C3.284 4.202.822 8.404 0 12.606 2.053 9.666 4.927 8.32 9.032 8.32v3.446l5.748-5.883z" fill="#c2c2c2" fill-rule="evenodd">
# </path>
# </svg>
# <span style="margin-left:5px">
#               Share
#              </span>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-12-12">
# <div class="aMaAEs">
# <div>
# <h1 class="yhB1nd">
# <span class="G6XhRU">
#             Eyebogler
#            </span>
# <span class="B_NuCI">
#             Color Block Men Hooded Neck White, Red, Black T-Shirt
#            </span>
# </h1>
# </div>
# <div class="_1V_ZGU pZkvcx">
# <span>
#            Special price
#           </span>
# </div>
# <div class="dyC4hf pZkvcx">
# <div class="CEmiEU">
# <div class="_25b18c">
# <div class="_30jeq3 _16Jk6d">
#              ₹349
#             </div>
# <div class="_3I9_wc _2p6lqe">
#              ₹
#              <!-- -->
#              1,299
#             </div>
# <div class="_3Ay6Sb _31Dcoz pZkvcx">
# <span>
#               73% off
#              </span>
# </div>
# </div>
# </div>
# <div class="_1V9q7_">
# <img class="_3ECE0V" id="price-info-icon" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/info-basic_6c1a38.svg"/>
# </div>
# </div>
# <div class="_3Zuayz">
# <div class="_3_L3jD">
# <div class="gUuXy- _16VRIQ _1eJXd3">
# <span class="_1lRcqv" id="productRating_LSTTSHFZMJ6CCRNPX5KB1BXDF_TSHFZMJ6CCRNPX5K_">
# <div class="_3LWZlK _3uSWvT">
#               4
#               <img class="_1wB99o _19cuvx" src="..."/>
# </div>
# </span>
# <span class="_2_R_DZ">
# <span>
#               15,897 ratings and 1,462 reviews
#              </span>
# </span>
# </div>
# </div>
# <span class="b7864- _2Z07dN">
# <img class="jMnjzX pZkvcx" height="21" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png"/>
# </span>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-12-12">
# <div class="_3Z0lU8">
# <div class="rd9nIL">
#           Available offers
#          </div>
# </div>
# <div class="_3TT44I">
# <div class="WT_FyS">
# <div class="XUp0WS">
# <span class="_3j4Zjq row">
# <img class="_3HLfAg" height="18" src="https://rukminim1.flixcart.com/www/36/36/promos/06/09/2016/c22c9fc4-0555-4460-8401-bf5c28d7ba29.png?q=90" width="18"/>
# <li class="_16eBzU col">
# <span class="u8dYXW">
#               Special Price
#              </span>
# <span>
#               Get extra 12% off (price inclusive of discount)
#              </span>
# <div class="Bv11UC _1qNw3R">
# <span class="fGhUR2">
#                T&amp;C
#               </span>
# </div>
# </li>
# </span>
# <span class="_3j4Zjq row">
# <img class="_3HLfAg" height="18" src="https://rukminim1.flixcart.com/www/36/36/promos/06/09/2016/c22c9fc4-0555-4460-8401-bf5c28d7ba29.png?q=90" width="18"/>
# <li class="_16eBzU col">
# <span class="u8dYXW">
#               Bank Offer
#              </span>
# <span>
#               5% Unlimited Cashback on Flipkart Axis Bank Credit Card
#              </span>
# <div class="Bv11UC _1qNw3R">
# <span class="fGhUR2">
#                T&amp;C
#               </span>
# </div>
# </li>
# </span>
# <span class="_3j4Zjq row">
# <img class="_3HLfAg" height="18" src="https://rukminim1.flixcart.com/www/36/36/promos/06/09/2016/c22c9fc4-0555-4460-8401-bf5c28d7ba29.png?q=90" width="18"/>
# <li class="_16eBzU col">
# <span class="u8dYXW">
#               Bank Offer
#              </span>
# <span>
#               20% off on 1st txn with Amex Network Cards issued by ICICI Bank,IndusInd Bank,SBI Cards and Mobikwik
#              </span>
# <div class="Bv11UC _1qNw3R">
# <span class="fGhUR2">
#                T&amp;C
#               </span>
# </div>
# </li>
# </span>
# <span class="_3j4Zjq row">
# <img class="_3HLfAg" height="18" src="https://rukminim1.flixcart.com/www/36/36/promos/06/09/2016/c22c9fc4-0555-4460-8401-bf5c28d7ba29.png?q=90" width="18"/>
# <li class="_16eBzU col">
# <span class="u8dYXW">
#               Bank Offer
#              </span>
# <span>
#               15% Instant discount on first Pay Later order of ₹500 and above
#              </span>
# <div class="Bv11UC _1qNw3R">
# <span class="fGhUR2">
#                T&amp;C
#               </span>
# </div>
# </li>
# </span>
# </div>
# <button class="_1JIkBw">
# <div class="row">
# <div class="IMZJg1 Okf99z">
# <span>
#               +1 more offer
#              </span>
# </div>
# </div>
# </button>
# </div>
# </div>
# </div>
# <div class="_1YokD2 _2GoDe3">
# <div class="_1YokD2 _3Mn1Gg col-6-12">
# <div class="_1AtVbE col-12-12" style="padding:32px 0px 0px 0px">
# <div class="_1NQxOU">
# <div class="_1lE4Yy">
# <img class="_3vWr8n" src="data:image/svg+xml;base64,..."/>
# <span class="_6eO2LF">
#              Deliver to
#             </span>
# </div>
# <div class="ibtBU6 _3t6eWY">
# <input autocomplete="off" class="cfnctZ" maxlength="6" placeholder="Enter delivery pincode" type="text" value=""/>
# <span class="UgLoKg jlIjY-">
#              Check
#             </span>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-12-12">
# <div class="row _2WVRLm _2HytE6">
# <div class="col col-12-12">
# <div class="_1SLzzw _2HytE6">
# <div class="_1OUluu">
# <ul class="eWlq4L">
# <div class="_20XEBf">
# <div class="_3XINqE">
#                  Usually delivered in
#                  <span class="_1TPvTK">
#                   3 days
#                  </span>
# <div class="Bv11UC">
# <span class="question">
#                    ?
#                   </span>
# </div>
# </div>
# <div class="_1dXn7l">
#                  Enter pincode for exact delivery dates/charges
#                 </div>
# </div>
# </ul>
# </div>
# <div class="_2O5gut">
# <span class="YxlyDn">
#                View Details
#               </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-6-12" style="padding:32px 0px 0px 52px">
# <div class="xDHSrl flex">
# <div class="_1YGsgZ">
#            Services
#           </div>
# <ul class="ZlRKeH">
# <li class="_2crLYm">
# <div class="me3OWC _1vBu0N">
# </div>
# <div class="_2MJMLX">
#              14 Days Return Policy
#              <div class="Bv11UC">
# <span class="question">
#                ?
#               </span>
# </div>
# </div>
# </li>
# <li class="_2crLYm">
# <div class="me3OWC eUF4ak">
# </div>
# <div class="_2MJMLX">
#              Cash on Delivery available
#              <div class="Bv11UC">
# <span class="question">
#                ?
#               </span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-12-12">
# <div class="_3wmLAA">
# <div class="ffYZ17 _3DM78Z col col-12-12">
# <div class="_22QfJJ">
# <span class="_1rcQuH _3DM78Z" id="Color">
#             Color
#            </span>
# <ul class="_1q8vHb">
# <li class="_3V2wfe _31hAvz" id="swatch-0-color">
# <a class="kmlXmn _31hAvz" data-img="http://rukmini1.flixcart.com/image/{@width}/{@height}/kkec4280/t-shirt/s/x/e/s-t345-blwhir-new-eyebogler-original-imafzr4yyf5qhf57.jpeg?q={@quality}" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itme298b2b1b912b?pid=TSHFZMJ6PH4HBRV4&amp;lid=LSTTSHFZMJ6PH4HBRV4FKXLBV&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;st=color">
# <div class="_2C41yO _1pH70n _31hAvz" data-img="http://rukmini1.flixcart.com/image/{@width}/{@height}/kkec4280/t-shirt/s/x/e/s-t345-blwhir-new-eyebogler-original-imafzr4yyf5qhf57.jpeg?q={@quality}">
# <img class="_30PAEw" src="https://rukminim1.flixcart.com/image/180/180/kkec4280/t-shirt/s/x/e/s-t345-blwhir-new-eyebogler-original-imafzr4yyf5qhf57.jpeg?q=50"/>
# </div>
# </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Black-White-Indigo Royal
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-1-color">
# <a class="kmlXmn _31hAvz" data-img="http://rukmini1.flixcart.com/image/{@width}/{@height}/kkec4280/t-shirt/g/q/o/xl-t345-blwhor-new-eyebogler-original-imafzr4y3ghsrgzh.jpeg?q={@quality}" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itme4d6d2984819d?pid=TSHFZMJ6CGPG7UHR&amp;lid=LSTTSHFZMJ6CGPG7UHRNNKXQQ&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;st=color">
# <div class="_2C41yO _1pH70n _31hAvz" data-img="http://rukmini1.flixcart.com/image/{@width}/{@height}/kkec4280/t-shirt/g/q/o/xl-t345-blwhor-new-eyebogler-original-imafzr4y3ghsrgzh.jpeg?q={@quality}">
# <img class="_30PAEw" src="https://rukminim1.flixcart.com/image/180/180/kkec4280/t-shirt/g/q/o/xl-t345-blwhor-new-eyebogler-original-imafzr4y3ghsrgzh.jpeg?q=50"/>
# </div>
# </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Black-White-Orange
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-2-color">
# <a class="kmlXmn PP89tw" data-img="http://rukmini1.flixcart.com/image/{@width}/{@height}/kkec4280/t-shirt/b/m/i/l-t345-blwhrd-new-eyebogler-original-imafzr4f7nxecr44.jpeg?q={@quality}" href="/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6CCRNPX5K&amp;lid=LSTTSHFZMJ6CCRNPX5KB1BXDF&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;st=color">
# <div class="_2C41yO _1pH70n _31hAvz" data-img="http://rukmini1.flixcart.com/image/{@width}/{@height}/kkec4280/t-shirt/b/m/i/l-t345-blwhrd-new-eyebogler-original-imafzr4f7nxecr44.jpeg?q={@quality}">
# <img class="_30PAEw" src="https://rukminim1.flixcart.com/image/180/180/kkec4280/t-shirt/b/m/i/l-t345-blwhrd-new-eyebogler-original-imafzr4f7nxecr44.jpeg?q=50"/>
# </div>
# </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Black-White-Red
#               </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="_2OTVHf _3duxeq z0fG_Y _1mQK5h _3MaULO _2wPDps _3DM78Z">
# <div class="_3Oikkn _3_ezix">
# <span>
#              Please select a Color to proceed
#             </span>
# <button class="_2KpZ6l FYrnUt">
#              ✕
#             </button>
# </div>
# </div>
# </div>
# <div class="ffYZ17 _3DM78Z col col-12-12">
# <div class="_22QfJJ">
# <span class="_1rcQuH _3DM78Z" id="Size">
#             Size
#            </span>
# <ul class="_1q8vHb">
# <li class="_3V2wfe _31hAvz" id="swatch-0-size">
# <a class="_1fGeJ5 _2UVyXR _1ynmf9" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itme298b2b1b912b?pid=TSHFZMJ6NVPGYGZM&amp;lid=LSTTSHFZMJ6NVPGYGZMBBGQUG&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;sattr[]=size&amp;st=size">
#               XS
#              </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Chest 17.8 inch | Length 36 inch | Shoulder 25.5 inch
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-1-size">
# <a class="_1fGeJ5 _2UVyXR _31hAvz" href="/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6CCRNPX5K&amp;lid=LSTTSHFZMJ6CCRNPX5KB1BXDF&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;sattr[]=size&amp;st=size">
#               S
#              </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Chest 18.8 inch | Length 37 inch | Shoulder 26 inch
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-2-size">
# <a class="_1fGeJ5 _2UVyXR _31hAvz" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6FAB6KAB3&amp;lid=LSTTSHFZMJ6FAB6KAB3ALL6ZB&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;sattr[]=size&amp;st=size">
#               M
#              </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Chest 19.8 inch | Length 39 inch | Shoulder 26.5 inch
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-3-size">
# <a class="_1fGeJ5 _2UVyXR _31hAvz" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6KFUXZYDC&amp;lid=LSTTSHFZMJ6KFUXZYDCKHZOCG&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;sattr[]=size&amp;st=size">
#               L
#              </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Chest 20.8 inch | Length 41 inch | Shoulder 27 inch
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-4-size">
# <a class="_1fGeJ5 _2UVyXR _31hAvz" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6WUBNQWCH&amp;lid=LSTTSHFZMJ6WUBNQWCHYBJBHI&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;sattr[]=size&amp;st=size">
#               XL
#              </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Chest 21.8 inch | Length 43 inch | Shoulder 27.5 inch
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-5-size">
# <a class="_1fGeJ5 _2UVyXR _31hAvz" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6DYWZVAF3&amp;lid=LSTTSHFZMJ6DYWZVAF3ZQSETC&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;sattr[]=size&amp;st=size">
#               XXL
#              </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                Chest 22.8 inch | Length 45 inch | Shoulder 28 inch
#               </div>
# </div>
# </li>
# <li class="_3V2wfe _31hAvz" id="swatch-6-size">
# <a class="_1fGeJ5 _2UVyXR _1ynmf9" href="/eyebogler-color-block-men-hooded-neck-multicolor-t-shirt/p/itme298b2b1b912b?pid=TSHFZMJ6Z22D3FHU&amp;lid=LSTTSHFZMJ6Z22D3FHUMKHC4P&amp;marketplace=FLIPKART&amp;sattr[]=color&amp;sattr[]=size&amp;st=size">
#               3XL
#              </a>
# <div class="_2OTVHf _3NVE7n _1mQK5h _2J-DXM">
# <div class="_3Oikkn _3_ezix _2KarXJ _31hAvz">
#                3XL
#               </div>
# </div>
# </li>
# <li class="_3F0T5D _31hAvz">
# <div class="_1qs4Jt">
# <span>
#                Size Chart
#               </span>
# <img class="VgkY_D" src="data:image/svg+xml;base64,..."/>
# </div>
# </li>
# </ul>
# </div>
# <div class="_2OTVHf _3duxeq z0fG_Y _1mQK5h _3MaULO _2wPDps _3DM78Z">
# <div class="_3Oikkn _3_ezix">
# <span>
#              Please select a Size to proceed
#             </span>
# <button class="_2KpZ6l FYrnUt">
#              ✕
#             </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_1YokD2 _3Mn1Gg">
# <div class="_1AtVbE col-12-12" style="padding:8px 0px 0px 0px">
# <div class="_1iWRKW">
# <div class="_1jneHk">
# <span>
#             Seller
#            </span>
# </div>
# <div>
# <div class="_1RLviY" id="sellerName">
# <span>
# <span>
#               SevenRocks
#              </span>
# <div class="_3LWZlK _1D-8OL">
#               4.3
#               <img class="_1wB99o" src="..."/>
# </div>
# </span>
# </div>
# <div class="xDHSrl">
# <ul class="_2-RJLI">
# <li class="_1UNqMC">
# <div class="_2MJMLX">
#                14 Days Return Policy
#                <div class="Bv11UC">
# <span class="question">
#                  ?
#                 </span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="_1YokD2 _2GoDe3" style="padding:24px 0px 0px 0px">
# <div class="_1AtVbE col-6-12" style="padding:0px 12px 0px 0px">
# <div>
# <div class="_2xlWlq">
# <div class="_3ywSr_" style="padding-top:23.89%">
# <div class="_1bEAQy _312yBx" style="padding-top:23.89%">
# <img alt="" class="_2OHU_q"/>
# <img alt="" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/lockin/100/24/images/CCO__PP_2019-07-14.png?q=50"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-12-12" style="padding:24px 0px 0px 0px">
# <div class="_3TOw5k">
# <div class="_2yIA0Y">
# <div class="row">
# <div class="col col-11-12 _2cLjiM">
#              Product Details
#             </div>
# <div class="col col-1-12 _2jufoV">
# <img src="..."/>
# </div>
# </div>
# <div class="row _i6Wtg">
# <div class="row _1v8OXw">
# <div class="X3BRps _13swYk">
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Type
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Hooded Neck
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Sleeve
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Full Sleeve
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Fit
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Regular
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Fabric
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Cotton Blend
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Sales Package
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Pack Of 1
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Pack of
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 1
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Style Code
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 T345-BLWHRD-NEW
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Neck Type
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Hooded Neck
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Ideal For
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Men
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Size
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 S
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Pattern
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Color Block
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Suitable For
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Western Wear
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Sleeve Type
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Narrow
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Reversible
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 No
#                </div>
# </div>
# <div class="row">
# <div class="col col-3-12 _2H87wv">
#                 Fabric Care
#                </div>
# <div class="col col-9-12 _2vZqPX">
#                 Gentle Machine Wash
#                </div>
# </div>
# <div class="_1AN87F">
#                Strut on the streets in comfort wearing this EYEBOGLER T-shirt. This unique creation is made using cotton. Be carefree and live the moment wearing this regular-fit T-shirt. The use of color will add to the charm of your personality. This is perfect for any casual occasion. The Seven Rocks premium EYEBOGLER brand combines absolute casualness with cool elegance. The company's values are based on its authentic fashion understanding heritage, dating back to the launch of the brand in 2015. Since then the brand has been further developed, taking influence from the latest Indian fashion trends, and is now a truly pure Indian Fashion Brand with pan India and abroad presence. Eyebogler offers a full range of clothing for men, women. In addition, Eyebogler has made deep inroads into the Men's shirt markets as well.
#               </div>
# <div class="zTAIgo">
#                Manufacturing, Packaging and Import Info
#               </div>
# </div>
# <button class="_2KpZ6l _1zH-yM">
#               Read More
#              </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_1AtVbE col-12-12">
# <div class="col JOpGWq _33R3aa">
# <div class="_3HKIdy">
# <div class="_2QKOHZ _33R3aa">
#             Ratings &amp; Reviews
#            </div>
# <div class="gUuXy- gP6o01 _1eJXd3">
# <span class="_1lRcqv" id="productRating_LSTTSHFZMJ6CCRNPX5KB1BXDF_TSHFZMJ6CCRNPX5K_">
# <div class="_3LWZlK _138NNC">
#               4
#               <img class="_1wB99o _1Tnj76" src="..."/>
# </div>
# </span>
# <span class="_2_R_DZ _2IRzS8">
# <span>
#               15,897 ratings and 1,462 reviews
#              </span>
# </span>
# </div>
# <div class="_3cH4s3 _33R3aa">
# <button class="_2KpZ6l _1q9yVr _33R3aa" type="submit">
# <span>
#               Rate Product
#              </span>
# </button>
# </div>
# </div>
# <div class="row">
# <div class="col col-12-12">
# </div>
# </div>
# <div class="_2c2kV- _33R3aa">
# <div class="_16PBlm _2RzJ9n">
# <div class="col">
# <div class="col _2wzgFH _1QgsS5">
# <div class="row">
# <div class="t-ZTKy _1QgsS5">
# <div>
# <div class="_3LWZlK _1BLPMq _3B8WaH">
#                   4
#                   <img class="_1wB99o" src="..."/>
# </div>
# <div class="_6K-7Co">
#                   Nice one !!
#                  </div>
# <span class="_1H-bmy">
# <span>
#                    READ MORE
#                   </span>
# </span>
# </div>
# </div>
# </div>
# <div class="_2nMSwX _3oLIki">
# <div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_289c948ddd164e08a2465b4eca3ec028.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px">
# </div>
# </div>
# <div class="row _3n8db9">
# <div class="row _1ExUpQ">
# <p class="_2sc7ZR _2V5EHH _1QgsS5">
#                  Flipkart Customer
#                 </p>
# <div>
# </div>
# <p class="_2sc7ZR">
#                  4months ago
#                 </p>
# <div class="_1e9_Zu">
# <div class="row">
# <div class="_27aTsS">
# <div class="_1LmwT9">
# <svg class="skCrcq" height="15" width="20" xmlns="http://www.w3.org/2000/svg">
# <path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.143V6.434H0z" fill="#fff" fill-rule="evenodd">
# </path>
# </svg>
# <span class="_3c3Px5">
#                      392
#                     </span>
# </div>
# <div class="_1LmwT9 pkR4jH">
# <svg class="skCrcq pkR4jH" height="15" width="20" xmlns="http://www.w3.org/2000/svg">
# <path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.143V6.434H0z" fill="#fff" fill-rule="evenodd">
# </path>
# </svg>
# <span class="_3c3Px5">
#                      77
#                     </span>
# </div>
# </div>
# <div class="_2bmov8">
# <img src="..."/>
# <div class="_3E8aIl _38dCuf">
# <div class="_3XCI6U">
# <a href="/reviews/eab20892-7c9b-4a3d-8f46-8508c1085870">
# <span>
#                        Permalink
#                       </span>
# </a>
# </div>
# <div class="_3XCI6U _2b2z-j">
# <span>
#                       Report Abuse
#                      </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg">
# <g>
# <circle cx="6" cy="6" fill="#878787" r="6">
# </circle>
# <path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5">
# </path>
# </g>
# </svg>
# <p class="_2mcZGG" id="review-eab20892-7c9b-4a3d-8f46-8508c1085870">
# <span>
#                  Certified Buyer
#                 </span>
# <span>
#                  , Kancheepuram
#                 </span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="_16PBlm _2RzJ9n">
# <div class="col">
# <div class="col _2wzgFH _1QgsS5">
# <div class="row">
# <div class="t-ZTKy _1QgsS5">
# <div>
# <div class="_3LWZlK _1BLPMq _3B8WaH">
#                   5
#                   <img class="_1wB99o" src="..."/>
# </div>
# <div class="_6K-7Co">
#                   Super quality and product 👍
#                  </div>
# <span class="_1H-bmy">
# <span>
#                    READ MORE
#                   </span>
# </span>
# </div>
# </div>
# </div>
# <div class="_2nMSwX _3oLIki">
# <div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202103/blobio-imr-202103_aa86f957e7c74fd3b558b5df23ebfb2f.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px">
# </div>
# </div>
# <div class="row _3n8db9">
# <div class="row _1ExUpQ">
# <p class="_2sc7ZR _2V5EHH _1QgsS5">
#                  Mehul Chaudhary
#                 </p>
# <div>
# </div>
# <p class="_2sc7ZR">
#                  8months ago
#                 </p>
# <div class="_1e9_Zu">
# <div class="row">
# <div class="_27aTsS">
# <div class="_1LmwT9">
# <svg class="skCrcq" height="15" width="20" xmlns="http://www.w3.org/2000/svg">
# <path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.143V6.434H0z" fill="#fff" fill-rule="evenodd">
# </path>
# </svg>
# <span class="_3c3Px5">
#                      1030
#                     </span>
# </div>
# <div class="_1LmwT9 pkR4jH">
# <svg class="skCrcq pkR4jH" height="15" width="20" xmlns="http://www.w3.org/2000/svg">
# <path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.143V6.434H0z" fill="#fff" fill-rule="evenodd">
# </path>
# </svg>
# <span class="_3c3Px5">
#                      227
#                     </span>
# </div>
# </div>
# <div class="_2bmov8">
# <img src="..."/>
# <div class="_3E8aIl _38dCuf">
# <div class="_3XCI6U">
# <a href="/reviews/5ec2d552-99b9-40a7-b571-89e721f379aa">
# <span>
#                        Permalink
#                       </span>
# </a>
# </div>
# <div class="_3XCI6U _2b2z-j">
# <span>
#                       Report Abuse
#                      </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg">
# <g>
# <circle cx="6" cy="6" fill="#878787" r="6">
# </circle>
# <path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5">
# </path>
# </g>
# </svg>
# <p class="_2mcZGG" id="review-5ec2d552-99b9-40a7-b571-89e721f379aa">
# <span>
#                  Certified Buyer
#                 </span>
# <span>
#                  , Palanpur
#                 </span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="_16PBlm _2RzJ9n">
# <div class="col">
# <div class="col _2wzgFH _1QgsS5">
# <div class="row">
# <div class="t-ZTKy _1QgsS5">
# <div>
# <div class="_3LWZlK _1BLPMq _3B8WaH">
#                   5
#                   <img class="_1wB99o" src="..."/>
# </div>
# <div class="_6K-7Co">
#                   It's very good products
#                  </div>
# <span class="_1H-bmy">
# <span>
#                    READ MORE
#                   </span>
# </span>
# </div>
# </div>
# </div>
# <div class="_2nMSwX _3oLIki">
# <div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202105/blobio-imr-202105_14803e1bdf8541678938ca41ac7942dc.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px">
# </div>
# <div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202105/blobio-imr-202105_ee1cf45bbf8c4a7da212f21458741971.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px">
# </div>
# </div>
# <div class="row _3n8db9">
# <div class="row _1ExUpQ">
# <p class="_2sc7ZR _2V5EHH _1QgsS5">
#                  Mainuddin  Sk
#                 </p>
# <div>
# </div>
# <p class="_2sc7ZR">
#                  6months ago
#                 </p>
# <div class="_1e9_Zu">
# <div class="row">
# <div class="_27aTsS">
# <div class="_1LmwT9">
# <svg class="skCrcq" height="15" width="20" xmlns="http://www.w3.org/2000/svg">
# <path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.143V6.434H0z" fill="#fff" fill-rule="evenodd">
# </path>
# </svg>
# <span class="_3c3Px5">
# ...
#                  </div>
# <div class="_2D27nh">
#                   Min 60% Off
#                  </div>
# <a class="_2KpZ6l tE1cUL" href="/mens-jeans/pr?sid=clo,vua,k58,i51&amp;marketplace=FLIPKART&amp;p[]=facets.discount_range_v1%5B%5D%3D60%25+or+more&amp;fm=productRecommendation%2FAugmentSelling&amp;iid=R%3Avc%3Bpt%3App%3Buid%3A72e52d7a-4c4c-11ec-ab7c-d72d34d8d879%3B.cid%3AS_F_N_clo_vua_k58_i51__d_60-100__NONE_ALL%3Bnid%3Aclo_vua_k58_i51_%3Bet%3AS%3Beid%3Aclo_vua_k58_i51_%3Bmp%3AF%3Bct%3Ad%3B&amp;ppt=None&amp;ppn=None&amp;ssid=1tpci2vbq80000001637665177179&amp;otracker=pp_reco_You%2Bmight%2Bbe%2Binterested%2Bin_4_36.dealCard.OMU_cid%3AS_F_N_clo_vua_k58_i51__d_60-100__NONE_ALL%3Bnid%3Aclo_vua_k58_i51_%3Bet%3AS%3Beid%3Aclo_vua_k58_i51_%3Bmp%3AF%3Bct%3Ad%3B&amp;otracker1=pp_reco_PINNED_productRecommendation%2FAugmentSelling_You%2Bmight%2Bbe%2Binterested%2Bin_BANNER_HORIZONTAL_dealCard_cc_4_NA_view-all&amp;cid=cid%3AS_F_N_clo_vua_k58_i51__d_60-100__NONE_ALL%3Bnid%3Aclo_vua_k58_i51_%3Bet%3AS%3Beid%3Aclo_vua_k58_i51_%3Bmp%3AF%3Bct%3Ad%3B">
# <span class="_2Ku_zz">
#                    Shop Now
#                   </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_35l9rN rek5UH _1tKnHb">
# <div class="_2kgArB _3y7w9p">
# <svg class="" height="24" viewbox="0 0 16 27" width="14.6" xmlns="http://www.w3.org/2000/svg">
# <path class="_23HYg_" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# </div>
# <div class="_35l9rN _31Mq1b">
# <div class="_2kgArB _2CP_Bu">
# <svg class="_1xtBwk" height="24" viewbox="0 0 16 27" width="14.6" xmlns="http://www.w3.org/2000/svg">
# <path class="_23HYg_" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_39SDPR">
# </div>
# </div>
# <footer class="_3voSl0">
# <div class="_3rc_xQ">
# <div class="row">
# <div class="col gu12 _8Qljeg">
# </div>
# </div>
# <div>
# <div class="_2WErco row">
# <div class="_2Brcj4">
# <div class="_3-dnWo">
#           ABOUT
#          </div>
# <a class="_1arVWX" href="/helpcentre?otracker=undefined_footer_navlinks">
#           Contact Us
#          </a>
# <a class="_1arVWX" href="/about-us?otracker=undefined_footer_navlinks">
#           About Us
#          </a>
# <a class="_1arVWX" href="https://www.flipkartcareers.com/?otracker=undefined_footer_navlinks">
#           Careers
#          </a>
# <a class="_1arVWX" href="http://stories.flipkart.com/?otracker=undefined_footer_navlinks">
#           Flipkart Stories
#          </a>
# <a class="_1arVWX" href="/s/press?otracker=undefined_footer_navlinks">
#           Press
#          </a>
# <a class="_1arVWX" href="https://www.flipkartwholesale.com/?otracker=undefined_footer_navlinks" target="_blank">
#           Flipkart Wholesale
#          </a>
# <a class="_1arVWX" href="/corporate-information">
#           Corporate Information
#          </a>
# </div>
# <div class="_2Brcj4">
# <div class="_3-dnWo">
#           HELP
#          </div>
# <a class="_1arVWX" href="/pages/payments">
#           Payments
#          </a>
# <a class="_1arVWX" href="/pages/shipping">
#           Shipping
#          </a>
# <a class="_1arVWX" href="/helpcentre?catalog=55c9c6edb000002e002c1701&amp;view=CATALOG">
#           Cancellation &amp; Returns
#          </a>
# <a class="_1arVWX" href="/helpcentre?catalog=55c9c8e2b0000023002c1702&amp;view=CATALOG">
#           FAQ
#          </a>
# <a class="_1arVWX" href="https://seller.flipkart.com/fiv?otracker=undefined_footer_navlinks">
#           Report Infringement
#          </a>
# </div>
# <div class="_2Brcj4">
# <div class="_3-dnWo">
#           POLICY
#          </div>
# <a class="_1arVWX" href="/pages/returnpolicy?otracker=undefined_footer_navlinks">
#           Return Policy
#          </a>
# <a class="_1arVWX" href="/pages/terms?otracker=undefined_footer_navlinks">
#           Terms Of Use
#          </a>
# <a class="_1arVWX" href="/pages/paymentsecurity?otracker=undefined_footer_navlinks">
#           Security
#          </a>
# <a class="_1arVWX" href="/pages/privacypolicy?otracker=undefined_footer_navlinks">
#           Privacy
#          </a>
# <a class="_1arVWX" href="/sitemap?otracker=undefined_footer_navlinks">
#           Sitemap
#          </a>
# <a class="_1arVWX" href="/pages/ewaste-compliance-tnc?otracker=undefined_footer_navlinks">
#           EPR Compliance
#          </a>
# </div>
# <div class="_2Brcj4">
# <div class="_3-dnWo">
#           SOCIAL
#          </div>
# <a class="_1arVWX" href="https://www.facebook.com/flipkart">
#           Facebook
#          </a>
# <a class="_1arVWX" href="https://www.twitter.com/flipkart">
#           Twitter
#          </a>
# <a class="_1arVWX" href="https://www.youtube.com/flipkart">
#           YouTube
#          </a>
# </div>
# <div class="_2Brcj4 address">
# <div class="_3JHi0r">
# <div class="_3-dnWo">
# <span>
#             Mail Us:
#            </span>
# </div>
# <div class="_1U1qnR">
# <div class="_1LJS6T">
# <div class="_2NKhZn _1U1qnR">
# <p>
#               Flipkart Internet Private Limited,
#              </p>
# <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
# <p>
#               Clove Embassy Tech Village,
#              </p>
# <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
# <p>
#               Bengaluru, 560103,
#              </p>
# <p>
#               Karnataka, India
#              </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_2Brcj4 address">
# <div class="_3IT4e6">
# <div class="_3-dnWo">
# <span>
#             Registered Office Address:
#            </span>
# </div>
# <div class="_1U1qnR">
# <div class="_1LJS6T">
# <div class="_2NKhZn _1U1qnR">
# <p>
#               Flipkart Internet Private Limited,
#              </p>
# <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
# <p>
#               Clove Embassy Tech Village,
#              </p>
# <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
# <p>
#               Bengaluru, 560103,
#              </p>
# <p>
#               Karnataka, India
#              </p>
# <p>
#               CIN : U51109KA2012PTC066107
#              </p>
# <p>
#               Telephone:
#               <a href="tel:18002029898">
#                1800 202 9898
#               </a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div class="_2uz0vJ">
# <div>
# <img src="data:image/svg+xml;base64,..."/>
# <a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect">
# <span class="hDTmm5">
#             Sell On Flipkart
#            </span>
# </a>
# </div>
# <div>
# <img src="data:image/svg+xml;base64,..."/>
# <a href="https://brands.flipkart.com">
# <span class="hDTmm5">
#             Advertise
#            </span>
# </a>
# </div>
# <div>
# <img src="data:image/svg+xml;base64,..."/>
# <a href="/the-gift-card-store?otracker=undefined_footer_footer_navlinks">
# <span class="hDTmm5">
#             Gift Cards
#            </span>
# </a>
# </div>
# <div>
# <img src="data:image/svg+xml;base64,..."/>
# <a href="/helpcentre?otracker=undefined_footer_footer_navlinks">
# <span class="hDTmm5">
#             Help Center
#            </span>
# </a>
# </div>
# <span class="z3ht-w">
#           © 2007-
#           <!-- -->
#           2021
#           <!-- -->
# <span>
#            Flipkart.com
#           </span>
# </span>
# <img src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/payment-method_69e7ec.svg"/>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <div class="_1EcK2J _38JCdA">
# <div class="bra6U8">
# <svg class="_2TdLiZ" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
# <path class="_3ZKfA2" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
# </path>
# </svg>
# <span>
#        Back to top
#       </span>
# </div>
# </div>
# </div>
# </div>
# <script nonce="13834811178714706440" type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }
#   </script>
# <script id="is_script" nonce="13834811178714706440">
#    window.__INITIAL_STATE__ = {"abExperiments":{"cco_platform_egv":{"value":true,"abId":"530616d6","expId":"EGV Checkout flow - Estrela Test Bucket"},"as-cache-aa":{"value":"aae","abId":"5412f0f0","expId":"Autosuggest_AA_12thNov"},"msite-homep-3e683":{"value":"gamif-homep-0ecb9","abId":"66428fb4","expId":"Gamification discovery widget"},"newap-homep-d9b50":{"value":"gamif-homep-811f8","abId":"66428fb4","expId":"Gamification discovery widget"},"newap-homep-55db3":{"value":"gamif-homep-811f8","abId":"66428fb4","expId":"Gamification discovery widget"},"msite-homep-7e8e7":{"value":"gamif-homep-0ecb9","abId":"66428fb4","expId":"Gamification discovery widget"},"dummyvariable_ads_1":{"value":true,"abId":"74399cb6","expId":"Da_Vinci_Control_23rd_March"},"COD_captcha_1":{"value":1,"abId":"ca431e8c","expId":"Control - Payments Page 2021-22"},"cod_captcha_2":{"value":1,"abId":"ca431e8c","expId":"Control - Payments Page 2021-22"},"card_eligibility_check":{"value":2,"abId":"ca431e8c","expId":"Control - Payments Page 2021-22"},"isFNBottomSheet":{"value":false,"abId":"d9100b28","expId":"Grocery Layer Control September - December"},"upSellAttachEnabled":{"value":false,"abId":"d9100b28","expId":"Grocery Layer Control September - December"},"crossSellAttachEnabled":{"value":false,"abId":"d9100b28","expId":"Grocery Layer Control September - December"},"highlightsv2Enabled":{"value":false,"abId":"f4cb1215","expId":"PP - New highlights - reverse"}},"activateVip":{"asyncStatus":"INIT","widget":[]},"autosuggest":{"query":null,"payloadId":null,"searchHistory":[],"asyncStatus":"INIT","words":{},"searchBrowseHistoryRequest":{}},"basket":{"asyncStatus":"INIT","pageLevelError":false},"buyingGuides":{"asyncStatus":"INIT"},"cartData":{"asyncStatus":"INIT","pageLevelError":false},"saveForLaterData":{"asyncStatus":"INIT","data":{"requestedStores":[]}},"checkoutPage":{"summary":{"asyncStatus":"INIT"},"checkoutAsyncStatus":"INIT","addressCache":{"newAddressForm":{"id":"newAddressForm","name":"","addressLine1":"","addressLine2":"","landmark":"","city":"","state":"","pincode":"","phone":"","alternatePhone":"","locationTypeTag":""}},"visualState":{"login":"EXPANDED","address":"COLLAPSED","orderSummary":"COLLAPSED","payment":"COLLAPSED"},"loginState":{"asyncStatus":"INIT"},"buyNow":{"eids":"","domain":"physical","analytics":{},"quantity":0},"addressLocation":{"asyncStatus":"INIT"},"staticPage":{"asyncStatus":"INIT"}},"claimedReward":{"asyncStatus":"INIT","widget":[]},"compareAddProductData":{"asyncStatus":"INIT","brandvsproduct":{},"brand":null},"compareBrandData":{"asyncStatus":"INIT"},"comparePageData":{"asyncStatus":"INIT","showDifference":false},"compareWidgetData":[],"config":{"asyncStatus":"SUCCESS","data":{"tooltip-zion-services":{"deliveryCharge":"## Shipping Charges For Non Flipkart Assured Items\n\n Shipping charges are calculated based on the number of units, distance and delivery date.\n\n For Plus as well as Non-Plus customers, Seller will decide shipping charges for all non-FAssured items.","deliverdBy":"## Shipping Charges For Flipkart Assured Items\n\n Shipping charges are calculated based on the number of units, distance and delivery date. \n\n For Plus customers, shipping charges are free.\n\n For non-Plus customers, if the total value of FAssured items is more than Rs.500, shipping charges are free.  If the total value of FAssured items is less than Rs.500, shipping charges = Rs.40 per unit\n\n\\* For faster delivery, shipping charges will be applicable","tentativeRelease":"__What is the tentative delivery time?__\n\n Sellers generally procure and ship the items within the time specified on the product page. Business days exclude public holidays and Sundays.\n\n Estimated delivery time depends on the following factors:\n * The Seller offering the product \n * Product's availability with the Seller \n * The destination to which you want the order shipped to and the Seller's location\n\n__Why does the delivery date not correspond to the delivery t ...
#   </script>
# <script nonce="13834811178714706440">
#    window.__BUNDLE_IDS__ = {"children":[{"id":"navMenu"}]};
#   </script>
# <script nonce="13834811178714706440">
#    window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;
#   </script>
# <script nonce="13834811178714706440">
#    if ('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") === -1) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") > -1){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }
#   </script>
# <script nonce="13834811178714706440" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/js/raven.3.22.3.js">
# </script>
# <script nonce="13834811178714706440">
#    window.Raven && window.Raven.config('https://b2fe488e344a47eda53b8d306edec9b7@sentry.flipkart.com/2',{
# 		release: '4.61.0',
# 		whitelistUrls: [
# 			/flipkart\.com/,
# 			/flixcart\.com/
# 		],
# 		ignoreErrors: [
# 			// Random plugins/extensions
# 			'top.GLOBALS',
# 			// See: http://blog.errorception.com/2012/03/tale-of-unfindable-js-error.html
# 			'originalCreateNotification',
# 			'canvas.contentDocument',
# 			'MyApp_RemoveAllHighlights',
# 			'atomicFindClose',
# 			// Facebook borked
# 			'fb_xd_fragment',
# 			// ISP "optimizing" proxy - `Cache-Control: no-transform` seems to reduce this. (thanks @acdha)
# 			// See http://stackoverflow.com/questions/4113268/how-to-stop-javascript-injection-from-vodafone-proxy
# 			'bmi_SafeAddOnload',
# 			'EBCallBackMessageReceived',
# 			'failed to fetch'
# 		],
# 		ignoreUrls: [
# 			// Facebook flakiness
# 			/graph\.facebook\.com/i,
# 			// Facebook blocked
# 			/connect\.facebook\.net\/en_US\/all\.js/i,
# 			// Chrome extensions
# 			/extensions\//i,
# 			/^chrome:\/\//i
# 		],
# 		sanitizeKeys: ['nsid', 'secureToken', 'SN'],
# 		environment: 'production',
# 		sampleRate: 0.5
# 	}).install();
# 	window.Raven && window.Raven.setUserContext({
# 		accountId: ''
# 	});
#   </script>
# <script async="" defer="defer" id="omni_script" nonce="13834811178714706440" src="//static-assets-web.flixcart.com/www/linchpin/batman-returns/omni/omni16.js">
# </script>
# <script nonce="13834811178714706440">
#    window._pxAppId = 'PXgNtTli3A';
#   </script>
# <script async="" nonce="13834811178714706440" src="//static-assets-web.flixcart.com/px/gNtTli3A/init.js">
# </script>
# </body>
# </html>

# %%
title=soup2.find(class_="G6XhRU")
title=title.get_text().replace('\n','').strip()

# %%
price=soup2.find(class_="_30jeq3 _16Jk6d").getText()
priced=price.replace('\n','').split()[0]
price=priced[1:]

# %%
rating=soup2.find(class_="_3LWZlK _3uSWvT").getText()
rating=rating.replace('\n','').split()[0]
rating
# Out:
# '4'

# %%
import datetime
date=datetime.date.today()
date
# Out:
# datetime.date(2021, 11, 23)

# %%
import csv
header= ['title','price','rating','date']
data=[title,price,rating,date]

with open('FlipkartScrapedtata.csv','w+',newline='',encoding='UTF8') as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\user hp\Desktop\Jupyter anaconda\Digikull\scrape\FlipkartScrapedtata.csv')
print(df)
# Out:
#        title  price  rating        date
# 0  Eyebogler    349       4  2021-11-23

# %%
with open('FlipkartScrapedtata.csv','a+',newline='',encoding='UTF8') as f:
    writer=csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    url='https://www.flipkart.com/eyebogler-color-block-men-hooded-neck-white-red-black-t-shirt/p/itm5b837b35126fa?pid=TSHFZMJ6CCRNPX5K&lid=LSTTSHFZMJ6CCRNPX5KB1BXDF&marketplace=FLIPKART&q=t+shirts&store=clo%2Fash%2Fank%2Fedy&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&fm=SEARCH&iid=8d42db2d-de9d-41c5-b5d6-0c3a5a8572b7.TSHFZMJ6CCRNPX5K.SEARCH&ppt=sp&ppn=sp&qH=04ad3bdbbe706182'

    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'
}
    page=requests.get(url=url,headers=headers)
    soup=BeautifulSoup(page.content,'html.parser')
    soup2=BeautifulSoup(soup.prettify(),'html.parser')
    title=soup2.find(class_="G6XhRU")
    title=title.get_text().replace('\n','').strip()
    
    price=soup2.find(class_="_30jeq3 _16Jk6d").getText()
    priced=price.replace('\n','').split()[0]
    price=priced[1:]
    
    import datetime
    date=datetime.date.today()
    date
    import csv
    header= ['title','price','rating','date']
    data=[title,price,rating,date]

    with open('FlipkartScrapedtata.csv','a+',newline='',encoding='UTF8') as f:
        writer=csv.writer(f)
        
        writer.writerow(data)

# %%
import time
while True:
    check_price()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-0fd375af4fa6> in <module>
#       1 import time
#       2 while True:
# ----> 3     check_price()
#       4     time.sleep(1)
#       5
#
# <ipython-input-215-0e8d400f9cfa> in check_price()
#       5     'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'
#       6 }
# ----> 7     page=requests.get(url=url,headers=headers)
#       8     soup=BeautifulSoup(page.content,'html.parser')
#       9     soup2=BeautifulSoup(soup.prettify(),'html.parser')
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# D:\anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# D:\anaconda\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# D:\anaconda\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# D:\anaconda\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# D:\anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# D:\anaconda\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user hp\Desktop\Jupyter anaconda\Digikull\scrape\FlipkartScrapedtata.csv')
df
# Out:
#         title  price  rating        date
# 0   Eyebogler    349       4  2021-11-23
# 1   Eyebogler    349       4  2021-11-23
# 2   Eyebogler    349       4  2021-11-23
# 3   Eyebogler    349       4  2021-11-23
# 4   Eyebogler    349       4  2021-11-23
# 5   Eyebogler    349       4  2021-11-23
# 6   Eyebogler    349       4  2021-11-23
# 7   Eyebogler    349       4  2021-11-23
# 8   Eyebogler    349       4  2021-11-23
# 9   Eyebogler    349       4  2021-11-23
# 10  Eyebogler    349       4  2021-11-23
# 11  Eyebogler    349       4  2021-11-23
# 12  Eyebogler    349       4  2021-11-23
# 13  Eyebogler    349       4  2021-11-23
# 14  Eyebogler    349       4  2021-11-23
